# %% [markdown]
# # Final Project
#
# ## Predict whether a mammogram mass is benign or malignant
#
# We'll be using the "mammographic masses" public dataset from the UCI repository (source: https://archive.ics.uci.edu/ml/datasets/Mammographic+Mass)
#
# This data contains 961 instances of masses detected in mammograms, and contains the following attributes:
#
#
#    1. BI-RADS assessment: 1 to 5 (ordinal)
#    2. Age: patient's age in years (integer)
#    3. Shape: mass shape: round=1 oval=2 lobular=3 irregular=4 (nominal)
#    4. Margin: mass margin: circumscribed=1 microlobulated=2 obscured=3 ill-defined=4 spiculated=5 (nominal)
#    5. Density: mass density high=1 iso=2 low=3 fat-containing=4 (ordinal)
#    6. Severity: benign=0 or malignant=1 (binominal)
#
# BI-RADS is an assesment of how confident the severity classification is; it is not a "predictive" attribute and so we will discard it. The age, shape, margin, and density attributes are the features that we will build our model with, and "severity" is the classification we will attempt to predict based on those attributes.
#
# Although "shape" and "margin" are nominal data types, which sklearn typically doesn't deal with well, they are close enough to ordinal that we shouldn't just discard them. The "shape" for example is ordered increasingly from round to irregular.
#
# A lot of unnecessary anguish and surgery arises from false positives arising from mammogram results. If we can build a better way to interpret them through supervised machine learning, it could improve a lot of lives.
#
# ## Your assignment
#
# Build a Multi-Layer Perceptron and train it to classify masses as benign or malignant based on its features.
#
# The data needs to be cleaned; many rows contain missing data, and there may be erroneous data identifiable as outliers as well.
#
# Remember to normalize your data first! And experiment with different topologies, optimizers, and hyperparameters.
#
# I was able to achieve over 80% accuracy - can you beat that?

# %%
# !pipenv install
# Out:
# Courtesy Notice:
# Pipenv found itself running within a virtual environment,  so it will
# automatically use that environment, instead of  creating its own for any
# project. You can set
# PIPENV_IGNORE_VIRTUALENVS=1 to force pipenv to ignore that environment and
# create  its own instead.
# You can set PIPENV_VERBOSITY=-1 to suppress this warning.
# To activate this project's virtualenv, run pipenv shell.
# Alternatively, run a command inside the virtualenv with pipenv run.
# To activate this project's virtualenv, run pipenv shell.
# Alternatively, run a command inside the virtualenv with pipenv run.
# Installing dependencies from Pipfile.lock (2e40ed)...

# %% [markdown]
# ## Let's begin: prepare your data
#
# Start by importing the mammographic_masses.data.txt file into a Pandas dataframe (hint: use read_csv) and take a look at it.

# %%
import pandas as pd

masses_data = pd.read_csv('data/mammographic_masses.data.txt')
masses_data.head()
# Out:
#    5  67  3 5.1 3.1  1
# 0  4  43  1   1   ?  1
# 1  5  58  4   5   3  1
# 2  4  28  1   1   3  0
# 3  5  74  1   5   ?  1
# 4  4  65  1   ?   3  0

# %% [markdown]
# Make sure you use the optional parmaters in read_csv to convert missing data (indicated by a ?) into NaN, and to add the appropriate column names (BI_RADS, age, shape, margin, density, and severity):

# %%
masses_data = pd.read_csv('data/mammographic_masses.data.txt', na_values=['?'], names = ['BI-RADS', 'age', 'shape', 'margin', 'density', 'severity'])
masses_data.head()
# Out:
#    BI-RADS   age  shape  margin  density  severity
# 0      5.0  67.0    3.0     5.0      3.0         1
# 1      4.0  43.0    1.0     1.0      NaN         1
# 2      5.0  58.0    4.0     5.0      3.0         1
# 3      4.0  28.0    1.0     1.0      3.0         0
# 4      5.0  74.0    1.0     5.0      NaN         1

# %% [markdown]
# Evaluate whether the data needs cleaning; your model is only as good as the data it's given. Hint: use describe() on the dataframe.

# %%
masses_data.describe()
# Out:
#           BI-RADS         age       shape      margin     density    severity
# count  959.000000  956.000000  930.000000  913.000000  885.000000  961.000000
# mean     4.348279   55.487448    2.721505    2.796276    2.910734    0.463059
# std      1.783031   14.480131    1.242792    1.566546    0.380444    0.498893
# min      0.000000   18.000000    1.000000    1.000000    1.000000    0.000000
# 25%      4.000000   45.000000    2.000000    1.000000    3.000000    0.000000
# 50%      4.000000   57.000000    3.000000    3.000000    3.000000    0.000000
# 75%      5.000000   66.000000    4.000000    4.000000    3.000000    1.000000
# max     55.000000   96.000000    4.000000    5.000000    4.000000    1.000000

# %% [markdown]
# There are quite a few missing values in the data set. Before we just drop every row that's missing data, let's make sure we don't bias our data in doing so. Does there appear to be any sort of correlation to what sort of data has missing fields? If there were, we'd have to try and go back and fill that data in.

# %%
masses_data.loc[(masses_data['age'].isnull()) |
              (masses_data['shape'].isnull()) |
              (masses_data['margin'].isnull()) |
              (masses_data['density'].isnull())]
# Out:
#      BI-RADS   age  shape  margin  density  severity
# 1        4.0  43.0    1.0     1.0      NaN         1
# 4        5.0  74.0    1.0     5.0      NaN         1
# 5        4.0  65.0    1.0     NaN      3.0         0
# 6        4.0  70.0    NaN     NaN      3.0         0
# 7        5.0  42.0    1.0     NaN      3.0         0
# ..       ...   ...    ...     ...      ...       ...
# 778      4.0  60.0    NaN     4.0      3.0         0
# 819      4.0  35.0    3.0     NaN      2.0         0
# 824      6.0  40.0    NaN     3.0      4.0         1
# 884      5.0   NaN    4.0     4.0      3.0         1
# 923      5.0   NaN    4.0     3.0      3.0         1
#
# [130 rows x 6 columns]

# %% [markdown]
# If the missing data seems randomly distributed, go ahead and drop rows with missing data. Hint: use dropna().

# %%
masses_data.dropna(inplace=True)
masses_data.describe()
# Out:
#           BI-RADS         age       shape      margin     density    severity
# count  830.000000  830.000000  830.000000  830.000000  830.000000  830.000000
# mean     4.393976   55.781928    2.781928    2.813253    2.915663    0.485542
# std      1.888371   14.671782    1.242361    1.567175    0.350936    0.500092
# min      0.000000   18.000000    1.000000    1.000000    1.000000    0.000000
# 25%      4.000000   46.000000    2.000000    1.000000    3.000000    0.000000
# 50%      4.000000   57.000000    3.000000    3.000000    3.000000    0.000000
# 75%      5.000000   66.000000    4.000000    4.000000    3.000000    1.000000
# max     55.000000   96.000000    4.000000    5.000000    4.000000    1.000000

# %% [markdown]
# Next you'll need to convert the Pandas dataframes into numpy arrays that can be used by scikit_learn. Create an array that extracts only the feature data we want to work with (age, shape, margin, and density) and another array that contains the classes (severity). You'll also need an array of the feature name labels.

# %%
all_features = masses_data[['age', 'shape',
                             'margin', 'density']].values


all_classes = masses_data['severity'].values

feature_names = ['age', 'shape', 'margin', 'density']

all_features
# Out:
# array([[67.,  3.,  5.,  3.],
#        [58.,  4.,  5.,  3.],
#        [28.,  1.,  1.,  3.],
#        ...,
#        [64.,  4.,  5.,  3.],
#        [66.,  4.,  5.,  3.],
#        [62.,  3.,  3.,  3.]])

# %% [markdown]
# Some of our models require the input data to be normalized, so go ahead and normalize the attribute data. Hint: use preprocessing.StandardScaler().

# %%
from sklearn import preprocessing

scaler = preprocessing.StandardScaler()
all_features_scaled = scaler.fit_transform(all_features)
all_features_scaled
# Out:
# array([[ 0.7650629 ,  0.17563638,  1.39618483,  0.24046607],
#        [ 0.15127063,  0.98104077,  1.39618483,  0.24046607],
#        [-1.89470363, -1.43517241, -1.157718  ,  0.24046607],
#        ...,
#        [ 0.56046548,  0.98104077,  1.39618483,  0.24046607],
#        [ 0.69686376,  0.98104077,  1.39618483,  0.24046607],
#        [ 0.42406719,  0.17563638,  0.11923341,  0.24046607]])

# %% [markdown]
# Now set up an actual MLP model using Keras:

# %%
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential

def create_model():
    model = Sequential()
    #4 feature inputs going into an 6-unit layer (more does not seem to help - in fact you can go down to 4)
    model.add(Dense(6, input_dim=4, kernel_initializer='normal', activation='relu'))
    # "Deep learning" turns out to be unnecessary - this additional hidden layer doesn't help either.
    #model.add(Dense(4, kernel_initializer='normal', activation='relu'))
    # Output layer with a binary classification (benign or malignant)
    model.add(Dense(1, kernel_initializer='normal', activation='sigmoid'))
    # Compile model; rmsprop seemed to work best
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model
# Out:
# 2024-12-13 10:35:55.453398: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-12-13 10:35:55.570251: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-12-13 10:35:56.575649: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-12-13 10:35:56.577384: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-12-13 10:35:57.535347: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# Make sure scikeras is installed (this has replaced tf.keras.wrappers.scikit_learn which we used previously)

# %%
# !pip install scikeras[tensorflow]
# Out:
# Collecting scikeras[tensorflow]
#   Downloading scikeras-0.12.0-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: packaging>=0.21 in /workspaces/aws-certified-ml-2025/.venv/lib/python3.8/site-packages (from scikeras[tensorflow]) (24.2)
# Requirement already satisfied: scikit-learn>=1.0.0 in /workspaces/aws-certified-ml-2025/.venv/lib/python3.8/site-packages (from scikeras[tensorflow]) (1.3.2)
# Collecting tensorflow<2.13.0,>=2.12.0 (from scikeras[tensorflow])
#   Downloading tensorflow-2.12.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.4 kB)
# Requirement already satisfied: numpy<2.0,>=1.17.3 in /workspaces/aws-certified-ml-2025/.venv/lib/python3.8/site-packages (from scikit-learn>=1.0.0->scikeras[tensorflow]) (1.24.3)
# Requirement already satisfied: scipy>=1.5.0 in /workspaces/aws-certified-ml-2025/.venv/lib/python3.8/site-packages (from scikit-learn>=1.0.0->scikeras[tensorflow]) (1.10.1)
# Requirement already satisfied: joblib>=1.1.1 in /workspaces/aws-certified-ml-2025/.venv/lib/python3.8/site-packages (from scikit-learn>=1.0.0->scikeras[tensorflow]) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /workspaces/aws-certified-ml-2025/.venv/lib/python3.8/site-packages (from scikit-learn>=1.0.0->scikeras[tensorflow]) (3.5.0)
# Requirement already satisfied: absl-py>=1.0.0 in /workspaces/aws-certified-ml-2025/.venv/lib/python3.8/site-packages (from tensorflow<2.13.0,>=2.12.0->scikeras[tensorflow]) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in /workspaces/aws-certified-ml-2025/.venv/lib/python3.8/site-packages (from tensorflow<2.13.0,>=2.12.0->scikeras[tensorflow]) (1.6.3)
# Requirement already satisfied: flatbuffers>=2.0 in /workspaces/aws-certified-ml-2025/.venv/lib/python3.8/site-packages (from tensorflow<2.13.0,>=2.12.0->scikeras[tensorflow]) (24.3.25)
# Collecting gast<=0.4.0,>=0.2.1 (from tensorflow<2.13.0,>=2.12.0->scikeras[tensorflow])
#   Using cached gast-0.4.0-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: google-pasta>=0.1.1 in /workspaces/aws-certified-ml-2025/.venv/lib/python3.8/site-packages (from tensorflow<2.13.0,>=2.12.0->scikeras[tensorflow]) (0.2.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /workspaces/aws-certified-ml-2025/.venv/lib/python3.8/site-packages (from tensorflow<2.13.0,>=2.12.0->scikeras[tensorflow]) (1.68.1)
# Requirement already satisfied: h5py>=2.9.0 in /workspaces/aws-certified-ml-2025/.venv/lib/python3.8/site-packages (from tensorflow<2.13.0,>=2.12.0->scikeras[tensorflow]) (3.11.0)
# Collecting jax>=0.3.15 (from tensorflow<2.13.0,>=2.12.0->scikeras[tensorflow])
#   Downloading jax-0.4.13.tar.gz (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 60.4 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting keras<2.13,>=2.12.0 (from tensorflow<2.13.0,>=2.12.0->scikeras[tensorflow])
#   Downloading keras-2.12.0-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: libclang>=13.0.0 in /workspaces/aws-certified-ml-2025/.venv/lib/python3.8/site-packages (from tensorflow<2.13.0,>=2.12.0->scikeras[tensorflow]) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /workspaces/aws-certified-ml-2025/.venv/lib/python3.8/site-packages (from tensorflow<2.13.0,>=2.12.0->scikeras[tensorflow]) (3.4.0)
# Collecting protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 (from tensorflow<2.13.0,>=2.12.0->scikeras[tensorflow])
#   Using cached protobuf-4.25.5-cp37-abi3-manylinux2014_x86_64.whl.metadata (541 bytes)
# Requirement already satisfied: setuptools in /workspaces/aws-certified-ml-2025/.venv/lib/python3.8/site-packages (from tensorflow<2.13.0,>=2.12.0->scikeras[tensorflow]) (75.3.0)
# Requirement already satisfied: six>=1.12.0 in /workspaces/aws-certified-ml-2025/.venv/lib/python3.8/site-packages (from tensorflow<2.13.0,>=2.12.0->scikeras[tensorflow]) (1.17.0)
# Collecting tensorboard<2.13,>=2.12 (from tensorflow<2.13.0,>=2.12.0->scikeras[tensorflow])
#   Downloading tensorboard-2.12.3-py3-none-any.whl.metadata (1.8 kB)
# Collecting tensorflow-estimator<2.13,>=2.12.0 (from tensorflow<2.13.0,>=2.12.0->scikeras[tensorflow])
#   Downloading tensorflow_estimator-2.12.0-py2.py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: termcolor>=1.1.0 in /workspaces/aws-certified-ml-2025/.venv/lib/python3.8/site-packages (from tensorflow<2.13.0,>=2.12.0->scikeras[tensorflow]) (2.4.0)
# Collecting typing-extensions<4.6.0,>=3.6.6 (from tensorflow<2.13.0,>=2.12.0->scikeras[tensorflow])
#   Using cached typing_extensions-4.5.0-py3-none-any.whl.metadata (8.5 kB)
# Collecting wrapt<1.15,>=1.11.0 (from tensorflow<2.13.0,>=2.12.0->scikeras[tensorflow])
#   Downloading wrapt-1.14.1-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /workspaces/aws-certified-ml-2025/.venv/lib/python3.8/site-packages (from tensorflow<2.13.0,>=2.12.0->scikeras[tensorflow]) (0.34.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /workspaces/aws-certified-ml-2025/.venv/lib/python3.8/site-packages (from astunparse>=1.6.0->tensorflow<2.13.0,>=2.12.0->scikeras[tensorflow]) (0.45.1)
# Collecting ml-dtypes>=0.1.0 (from jax>=0.3.15->tensorflow<2.13.0,>=2.12.0->scikeras[tensorflow])
#   Downloading ml_dtypes-0.2.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Requirement already satisfied: importlib-metadata>=4.6 in /workspaces/aws-certified-ml-2025/.venv/lib/python3.8/site-packages (from jax>=0.3.15->tensorflow<2.13.0,>=2.12.0->scikeras[tensorflow]) (8.5.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /workspaces/aws-certified-ml-2025/.venv/lib/python3.8/site-packages (from tensorboard<2.13,>=2.12->tensorflow<2.13.0,>=2.12.0->scikeras[tensorflow]) (2.37.0)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /workspaces/aws-certified-ml-2025/.venv/lib/python3.8/site-packages (from tensorboard<2.13,>=2.12->tensorflow<2.13.0,>=2.12.0->scikeras[tensorflow]) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /workspaces/aws-certified-ml-2025/.venv/lib/python3.8/site-packages (from tensorboard<2.13,>=2.12->tensorflow<2.13.0,>=2.12.0->scikeras[tensorflow]) (3.7)
# Requirement already satisfied: requests<3,>=2.21.0 in /workspaces/aws-certified-ml-2025/.venv/lib/python3.8/site-packages (from tensorboard<2.13,>=2.12->tensorflow<2.13.0,>=2.12.0->scikeras[tensorflow]) (2.32.3)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /workspaces/aws-certified-ml-2025/.venv/lib/python3.8/site-packages (from tensorboard<2.13,>=2.12->tensorflow<2.13.0,>=2.12.0->scikeras[tensorflow]) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /workspaces/aws-certified-ml-2025/.venv/lib/python3.8/site-packages (from tensorboard<2.13,>=2.12->tensorflow<2.13.0,>=2.12.0->scikeras[tensorflow]) (3.0.6)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /workspaces/aws-certified-ml-2025/.venv/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow<2.13.0,>=2.12.0->scikeras[tensorflow]) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /workspaces/aws-certified-ml-2025/.venv/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow<2.13.0,>=2.12.0->scikeras[tensorflow]) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /workspaces/aws-certified-ml-2025/.venv/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow<2.13.0,>=2.12.0->scikeras[tensorflow]) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /workspaces/aws-certified-ml-2025/.venv/lib/python3.8/site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow<2.13.0,>=2.12.0->scikeras[tensorflow]) (2.0.0)
# Requirement already satisfied: zipp>=3.20 in /workspaces/aws-certified-ml-2025/.venv/lib/python3.8/site-packages (from importlib-metadata>=4.6->jax>=0.3.15->tensorflow<2.13.0,>=2.12.0->scikeras[tensorflow]) (3.20.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /workspaces/aws-certified-ml-2025/.venv/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow<2.13.0,>=2.12.0->scikeras[tensorflow]) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /workspaces/aws-certified-ml-2025/.venv/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow<2.13.0,>=2.12.0->scikeras[tensorflow]) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /workspaces/aws-certified-ml-2025/.venv/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow<2.13.0,>=2.12.0->scikeras[tensorflow]) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /workspaces/aws-certified-ml-2025/.venv/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow<2.13.0,>=2.12.0->scikeras[tensorflow]) (2024.8.30)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /workspaces/aws-certified-ml-2025/.venv/lib/python3.8/site-packages (from werkzeug>=1.0.1->tensorboard<2.13,>=2.12->tensorflow<2.13.0,>=2.12.0->scikeras[tensorflow]) (2.1.5)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /workspaces/aws-certified-ml-2025/.venv/lib/python3.8/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow<2.13.0,>=2.12.0->scikeras[tensorflow]) (0.6.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /workspaces/aws-certified-ml-2025/.venv/lib/python3.8/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow<2.13.0,>=2.12.0->scikeras[tensorflow]) (3.2.2)
# Downloading tensorflow-2.12.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (585.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 585.9/585.9 MB 32.9 MB/s eta 0:00:0000:0100:01
# Downloading scikeras-0.12.0-py3-none-any.whl (27 kB)
# Using cached gast-0.4.0-py3-none-any.whl (9.8 kB)
# Downloading keras-2.12.0-py2.py3-none-any.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 56.5 MB/s eta 0:00:00
# Using cached protobuf-4.25.5-cp37-abi3-manylinux2014_x86_64.whl (294 kB)
# Downloading tensorboard-2.12.3-py3-none-any.whl (5.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 68.8 MB/s eta 0:00:00
# Downloading tensorflow_estimator-2.12.0-py2.py3-none-any.whl (440 kB)
# Using cached typing_extensions-4.5.0-py3-none-any.whl (27 kB)
# Downloading wrapt-1.14.1-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (81 kB)
# Downloading ml_dtypes-0.2.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 56.0 MB/s eta 0:00:00
# Building wheels for collected packages: jax
#   Building wheel for jax (pyproject.toml) ... done
#   Created wheel for jax: filename=jax-0.4.13-py3-none-any.whl size=1518703 sha256=77d49cbac2c697a10b997ea500b55142c55f4b93594d81a0f827930e3ef842a6
#   Stored in directory: /home/codespace/.cache/pip/wheels/46/d9/15/d2800d4089dc4c77299ac7513c6aa1036f5491edbd2bf6ba16
# Successfully built jax
# Installing collected packages: wrapt, typing-extensions, tensorflow-estimator, protobuf, ml-dtypes, keras, gast, jax, scikeras, tensorboard, tensorflow
#   Attempting uninstall: wrapt
#     Found existing installation: wrapt 1.17.0
#     Uninstalling wrapt-1.17.0:
#       Successfully uninstalled wrapt-1.17.0
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.12.2
#     Uninstalling typing_extensions-4.12.2:
#       Successfully uninstalled typing_extensions-4.12.2
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.13.0
#     Uninstalling tensorflow-estimator-2.13.0:
#       Successfully uninstalled tensorflow-estimator-2.13.0
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 5.29.1
#     Uninstalling protobuf-5.29.1:
#       Successfully uninstalled protobuf-5.29.1
#   Attempting uninstall: keras
#     Found existing installation: keras 2.13.1
#     Uninstalling keras-2.13.1:
#       Successfully uninstalled keras-2.13.1
#   Attempting uninstall: gast
#     Found existing installation: gast 0.6.0
#     Uninstalling gast-0.6.0:
#       Successfully uninstalled gast-0.6.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.13.0
#     Uninstalling tensorboard-2.13.0:
#       Successfully uninstalled tensorboard-2.13.0
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.13.1
#     Uninstalling tensorflow-2.13.1:
#       Successfully uninstalled tensorflow-2.13.1
# Successfully installed gast-0.4.0 jax-0.4.13 keras-2.12.0 ml-dtypes-0.2.0 protobuf-4.25.5 scikeras-0.12.0 tensorboard-2.12.3 tensorflow-2.12.1 tensorflow-estimator-2.12.0 typing-extensions-4.5.0 wrapt-1.14.1

# %%
from sklearn.model_selection import cross_val_score
from scikeras.wrappers import KerasClassifier, KerasRegressor

# Wrap our Keras model in an estimator compatible with scikit_learn
estimator = KerasClassifier(build_fn=create_model, epochs=100, verbose=0)
# Now we can use scikit_learn's cross_val_score to evaluate this model identically to the others
cv_scores = cross_val_score(estimator, all_features_scaled, all_classes, cv=10)
cv_scores.mean()
# Out:
# 2024-12-13 10:36:46.546450: E tensorflow/tsl/lib/monitoring/collection_registry.cc:81] Cannot register 2 metrics with the same name: /tensorflow/api/keras/data_adapters
# ---------------------------------------------------------------------------
# AlreadyExistsError                        Traceback (most recent call last)
# Cell In[16], line 2
#       1 from sklearn.model_selection import cross_val_score
# ----> 2 from scikeras.wrappers import KerasClassifier, KerasRegressor
#       4 # Wrap our Keras model in an estimator compatible with scikit_learn
#       5 estimator = KerasClassifier(build_fn=create_model, epochs=100, verbose=0)
#
# File /workspaces/aws-certified-ml-2025/.venv/lib/python3.8/site-packages/scikeras/wrappers.py:22
#      20 from tensorflow.keras import losses as losses_module
#      21 from tensorflow.keras.models import Model
# ---> 22 from tensorflow.keras.utils import register_keras_serializable
#      24 from scikeras._utils import (
#      25     accepts_kwargs,
#      26     get_loss_class_function_or_string,
#    (...)
#      32     unflatten_params,
#      33 )
#      34 from scikeras.utils import loss_name, metric_name
#
# File /workspaces/aws-certified-ml-2025/.venv/lib/python3.8/site-packages/keras/api/_v2/keras/utils/__init__.py:10
#       8 from keras.api._v2.keras.utils import experimental
#       9 from keras.api._v2.keras.utils import legacy
# ---> 10 from keras.engine.data_adapter import pack_x_y_sample_weight
#      11 from keras.engine.data_adapter import unpack_x_y_sample_weight
#      12 from keras.saving.legacy.serialization import deserialize_keras_object
#
# File /workspaces/aws-certified-ml-2025/.venv/lib/python3.8/site-packages/keras/engine/data_adapter.py:48
#      45 except ImportError:
#      46     pd = None
# ---> 48 keras_data_adapter_gauge = tf.__internal__.monitoring.BoolGauge(
#      49     "/tensorflow/api/keras/data_adapters", "keras data adapter usage", "method"
#      50 )
#      53 class DataAdapter(object, metaclass=abc.ABCMeta):
#      54     """Base class for input data adapter.
#      55
#      56     In TF 2.0, tf.data is the preferred API for user to feed in data. In order
#    (...)
#      77     ```
#      78     """
#
# File /workspaces/aws-certified-ml-2025/.venv/lib/python3.8/site-packages/tensorflow/python/eager/monitoring.py:356, in BoolGauge.__init__(self, name, description, *labels)
#     348 def __init__(self, name, description, *labels):
#     349   """Creates a new BoolGauge.
#     350
#     351   Args:
#    (...)
#     354     *labels: The label list of the new metric.
#     355   """
# --> 356   super(BoolGauge, self).__init__('BoolGauge', _bool_gauge_methods,
#     357                                   len(labels), name, description, *labels)
#
# File /workspaces/aws-certified-ml-2025/.venv/lib/python3.8/site-packages/tensorflow/python/eager/monitoring.py:131, in Metric.__init__(self, metric_name, metric_methods, label_length, *args)
#     127 if label_length >= len(self._metric_methods):
#     128   raise ValueError('Cannot create {} metric with label >= {}'.format(
#     129       self._metric_name, len(self._metric_methods)))
# --> 131 self._metric = self._metric_methods[self._label_length].create(*args)
#
# AlreadyExistsError: Another metric with the same name already exists.

# %% [markdown]
# ## How did you do?
#
# Which topology, and which choice of hyperparameters, performed the best? Feel free to share your results!
